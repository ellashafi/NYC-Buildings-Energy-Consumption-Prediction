# %% [markdown]
# In this notebook, statistical features of the linear regression model is evaluated.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import norm
import pickle

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
def log_plus_one(x):
    return np.log(x+1)

# %%
df = pd.read_csv('nyc_bldg2021_model_ready.csv')

with open("lr_model.pickle", "rb") as f:
    lr = pickle.load(f)

with open("X_train_ct.pickle", "rb") as f:
    X_train = pickle.load(f)

with open("y_train.pickle", "rb") as f:
    y = pickle.load(f)

with open("column_transformer.pickle", "rb") as f:
    ct = pickle.load(f)

with open("one_hot_encoder.pickle", "rb") as f:
    oh = pickle.load(f)

# %%
lr.coef_
lr.intercept_
# Out:
# 94.39994644348454

# %%
X0 = np.ones((X_train.shape[0],1))
X = np.concatenate((X0, X_train), axis=1)

# %%
XTX_inv = np.linalg.inv(X.T @ X)
betas = XTX_inv @ (X.T @ y)
betas
# Out:
# array([ 9.43999428e+01,  1.79625404e+03, -1.03939873e+04,  1.13677152e+04,
#         1.11612974e+03, -6.68351158e+02, -1.11517849e+03,  2.74067093e+02,
#         2.64043132e+02,  1.48963214e+02,  2.85398761e+03,  2.91836306e+03,
#         1.91331893e+01, -2.64234917e+01,  1.79814481e+02, -3.09932010e+03,
#         4.14024828e+00,  6.94575896e+00, -1.14842267e+03, -7.95710928e+00,
#        -4.57170369e+00,  3.50369137e+00,  5.86430312e+01,  2.86290657e+02,
#        -1.93733076e+03, -9.40297390e+00, -5.06835572e+01, -1.20083832e+04,
#         3.30848343e+01, -1.37014696e+01,  1.52735016e+02, -3.85709725e+02,
#         4.62087541e+03,  9.68429259e+00,  1.30073935e+01,  1.55578217e+04,
#        -4.35731834e+01,  1.58705727e+01, -2.38053843e+02, -6.84162295e+02,
#        -9.92200274e-01,  1.81445764e+02,  4.34981651e+02, -1.79505932e+01,
#         1.31933764e+02,  1.36803898e+01,  3.66277092e+02, -3.74870663e+03,
#        -7.29228047e+02, -1.38209192e+02, -3.22151393e+03, -3.86536913e+02,
#        -1.26958057e+00, -7.49296357e+02, -2.26350252e+00,  6.94827944e-01,
#        -1.21026505e+00, -3.28747038e+03,  1.07100853e+01, -3.96128096e+00,
#         6.73843216e+01, -9.29432446e+00, -2.25238796e+02,  2.55164981e+03,
#        -2.85108585e+00, -7.81785411e-01,  5.25004065e+00, -1.10450858e+00,
#        -1.05973674e-01,  4.45355634e+00,  3.63605779e+00,  4.75845840e+00,
#         1.66817328e+00, -1.51650800e+01, -1.51724188e+01, -1.17862291e+02,
#         2.96860767e+01,  1.03528314e+00,  8.39781901e-01, -1.48249566e+00,
#        -1.67538788e+00,  3.13858565e+00, -2.92586251e+00, -1.37110416e+00,
#        -1.13348639e+01, -3.97042536e-01,  4.08182347e+00])

# %%
y_hat = X @ betas
resid_sq = (y - y_hat) ** 2

# %%
D = np.diag(resid_sq)

# %%
D.shape
# Out:
# (8624, 8624)

# %%
beta_vcov = XTX_inv @ (X.T @ D @ X) @ XTX_inv

# %%
np.diag(beta_vcov)
# Out:
# array([5.53642730e+02, 2.74831264e+06, 2.24390415e+07, 2.52275993e+07,
#        1.53540003e+05, 1.20774207e+05, 1.30610466e+05, 2.39642006e+06,
#        1.61734703e+04, 1.40063561e+05, 7.22521129e+05, 5.45440079e+05,
#        4.99281434e+01, 6.72423140e+01, 3.76076045e+03, 1.72583259e+05,
#        2.83308811e+00, 3.90418213e+00, 2.02066674e+06, 6.89613682e+01,
#        1.42133152e+00, 5.16277471e-01, 3.05586629e+02, 3.31135674e+04,
#        3.63408746e+06, 6.49515119e+01, 3.02579218e+02, 1.88164892e+07,
#        9.66030732e+02, 1.77807537e+02, 1.75435568e+04, 6.06955597e+04,
#        4.28064613e+06, 1.13759332e+02, 1.06271296e+02, 2.17558113e+07,
#        1.46546624e+03, 2.29022442e+02, 2.08782122e+04, 1.15006452e+04,
#        1.99372947e+02, 1.37007076e+04, 1.06599115e+05, 8.13695880e+01,
#        9.56862452e+02, 5.45749715e+01, 1.13313772e+04, 4.12535372e+05,
#        1.05493039e+05, 2.51102216e+04, 6.50371396e+04, 3.30002504e+04,
#        1.81262835e+01, 9.44766203e+04, 2.26987221e+00, 2.19994651e+00,
#        4.21378003e-01, 1.80659727e+06, 9.37014292e+01, 4.86505977e+00,
#        2.73834913e+02, 5.61597945e+04, 5.31251618e+05, 3.86154802e+05,
#        1.68426404e+01, 2.05494515e+01, 1.19062556e+00, 1.72692020e+00,
#        1.57195317e+00, 7.58730671e-01, 8.97477775e-01, 1.18569030e+01,
#        7.24163217e+00, 5.66237609e+02, 5.50720983e+02, 1.63900492e+03,
#        6.78851743e+02, 3.55433370e-01, 7.07891882e-01, 5.90702742e-01,
#        2.50456616e+00, 2.30850132e+01, 6.07073190e+00, 1.76482485e-01,
#        2.74517412e+01, 1.11465447e+00, 7.25087913e+00])

# %%
beta_se = np.sqrt(np.diag(beta_vcov))
t_stat = betas / beta_se
t_stat.shape
# Out:
# (87,)

# %%
features = ["Intercept"] + list(X_train.columns)

# %%
p_value = 2 * (1 - norm.cdf(np.abs(t_stat)))
p_value
# Out:
# array([6.02159127e-05, 2.78580160e-01, 2.82196483e-02, 2.36194179e-02,
#        4.39370066e-03, 5.44587415e-02, 2.03065374e-03, 8.59475683e-01,
#        3.78736536e-02, 6.90607637e-01, 7.86270229e-04, 7.76516223e-05,
#        6.77332738e-03, 1.27156328e-03, 3.36619406e-03, 8.61533067e-14,
#        1.39022034e-02, 4.39360864e-04, 4.19151574e-01, 3.37966121e-01,
#        1.25722217e-04, 1.08132062e-06, 7.94609738e-04, 1.15655534e-01,
#        3.09504193e-01, 2.43319170e-01, 3.57152192e-03, 5.63472572e-03,
#        2.87115764e-01, 3.04173684e-01, 2.48855374e-01, 1.17441179e-01,
#        2.55215334e-02, 3.63890884e-01, 2.07029371e-01, 8.51456782e-04,
#        2.55022974e-01, 2.94313646e-01, 9.94528848e-02, 1.77473147e-10,
#        9.43979240e-01, 1.21104138e-01, 1.82769578e-01, 4.65936254e-02,
#        1.99795315e-05, 6.40498726e-02, 5.79844599e-04, 5.33157785e-09,
#        2.47564806e-02, 3.83104130e-01, 0.00000000e+00, 3.33530385e-02,
#        7.65551442e-01, 1.47784675e-02, 1.32998566e-01, 6.39456671e-01,
#        6.22622605e-02, 1.44508052e-02, 2.68544989e-01, 7.25042357e-02,
#        4.65986410e-05, 9.68715169e-01, 7.57302808e-01, 4.02217108e-05,
#        4.87235399e-01, 8.63076198e-01, 1.49846793e-06, 4.00633264e-01,
#        9.32640108e-01, 3.17332726e-07, 1.23978212e-04, 1.66998474e-01,
#        5.35322410e-01, 5.23928084e-01, 5.17935857e-01, 3.59945326e-03,
#        2.54548254e-01, 8.24717528e-02, 3.18220854e-01, 5.37437051e-02,
#        2.89762857e-01, 5.13605298e-01, 2.35030706e-01, 1.09940091e-03,
#        3.05125186e-02, 7.06866005e-01, 1.29554940e-01])

# %%
coef_stat = pd.DataFrame({
    "feature": features, 
    "coef": betas,
    "standard_error": beta_se, 
    "t_stat" : t_stat, 
    "p_value" : p_value

})

# %%
coef_stat.sort_values(by=['coef'], ascending=False)
# Out:
#                                               feature          coef  standard_error     t_stat       p_value
# 35  Property.GFA.Calculated.Buildings.and.Parking....  15557.821671     4664.312525   3.335502  8.514568e-04
# 3    Property.GFA.Calculated.Buildings.and.Parking.ft  11367.715199     5022.708363   2.263264  2.361942e-02
# 32  Property.GFA.Calculated.Buildings.and.Parking....   4620.875411     2068.972240   2.233416  2.552153e-02
# 11                 Percent.of.Electricity.Green.Power   2918.363058      738.539152   3.951535  7.765162e-05
# 10                                  ENERGY.STAR.Score   2853.987610      850.012429   3.357583  7.862702e-04
# 63       Longitude Percent.of.Electricity.Green.Power   2551.649808      621.413552   4.106202  4.022171e-05
# 1   Weather.Normalized.Site.Natural.Gas.Intensity....   1796.254040     1657.803559   1.083514  2.785802e-01
# 4                                          Year.Built   1116.129737      391.841809   2.848419  4.393701e-03
# 42                               Year.Built Longitude    434.981651      326.495199   1.332276  1.827696e-01
# 46  Latitude Multifamily.Housing.Percent.That.Can....    366.277092      106.448942   3.440871  5.798446e-04
# 23  Multifamily.Housing.Gross.Floor.Area.ft Year.B...    286.290657      181.971337   1.573273  1.156555e-01
# 7   Electricity.Use...Grid.Purchase.and.Generated....    274.067093     1548.037487   0.177042  8.594757e-01
# 8                                           Longitude    264.043132      127.174960   2.076220  3.787365e-02
# 41  Year.Built Electricity.Use...Grid.Purchase.and...    181.445764      117.050022   1.550156  1.211041e-01
# 14  Weather.Normalized.Site.Natural.Gas.Intensity....    179.814481       61.325039   2.932154  3.366194e-03
# 30  Multifamily.Housing.Gross.Floor.Area.ft Percen...    152.735016      132.452092   1.153134  2.488554e-01
# 9      Multifamily.Housing.Percent.That.Can.Be.Heated    148.963214      374.250666   0.398031  6.906076e-01
# 44                       Year.Built ENERGY.STAR.Score    131.933764       30.933193   4.265119  1.997953e-05
# 0                                           Intercept     94.399943       23.529614   4.011963  6.021591e-05
# 60  Electricity.Use...Grid.Purchase.and.Generated....     67.384322       16.547958   4.072063  4.659864e-05
# 22  Multifamily.Housing.Gross.Floor.Area.ft Proper...     58.643031       17.481036   3.354666  7.946097e-04
# 28  Multifamily.Housing.Gross.Floor.Area.ft Multif...     33.084834       31.081035   1.064470  2.871158e-01
# 76            Property.Type_Residential Care Facility     29.686077       26.054783   1.139371  2.545483e-01
# 12  Weather.Normalized.Site.Natural.Gas.Intensity....     19.133189        7.065985   2.707788  6.773327e-03
# 37  Property.GFA.Calculated.Buildings.and.Parking....     15.870573       15.133487   1.048706  2.943136e-01
# 45      Year.Built Percent.of.Electricity.Green.Power     13.680390        7.387487   1.851833  6.404987e-02
# 34  Property.GFA.Calculated.Buildings.and.Parking....     13.007393       10.308797   1.261776  2.070294e-01
# 58  Electricity.Use...Grid.Purchase.and.Generated....     10.710085        9.679950   1.106420  2.685450e-01
# 33  Property.GFA.Calculated.Buildings.and.Parking....      9.684293       10.665802   0.907976  3.638909e-01
# 17  Weather.Normalized.Site.Natural.Gas.Intensity....      6.945759        1.975900   3.515238  4.393609e-04
# 66  ENERGY.STAR.Score Percent.of.Electricity.Green...      5.250041        1.091158   4.811440  1.498468e-06
# 71                                  Borough_STATEN IS      4.758458        3.443385   1.381913  1.669985e-01
# 69                                  Borough_MANHATTAN      4.453556        0.871051   5.112851  3.173327e-07
# 16  Weather.Normalized.Site.Natural.Gas.Intensity....      4.140248        1.683178   2.459780  1.390220e-02
# 86  Multifamily.Housing.Resident.Population.Type_O...      4.081823        2.692746   1.515859  1.295549e-01
# 70                                     Borough_QUEENS      3.636058        0.947353   3.838123  1.239782e-04
# 21  Weather.Normalized.Site.Natural.Gas.Intensity....      3.503691        0.718525   4.876231  1.081321e-06
# 81                     number.of.energy.meters.cat_25      3.138586        4.804687   0.653234  5.136053e-01
# 72  Estimated.Data.Flag...Electricity..Grid.Purcha...      1.668173        2.691028   0.619902  5.353224e-01
# 77  Multifamily.Housing.Government.Subsidized.Hous...      1.035283        0.596182   1.736521  8.247175e-02
# 78                                   Occupancy100_1.0      0.839782        0.841363   0.998121  3.182209e-01
# 55  Multifamily.Housing.Percent.That.Can.Be.Cooled...      0.694828        1.483222   0.468459  6.394567e-01
# 68                                   Borough_BROOKLYN     -0.105974        1.253776  -0.084524  9.326401e-01
# 85  Multifamily.Housing.Resident.Population.Type_N...     -0.397043        1.055772  -0.376068  7.068660e-01
# 65  Multifamily.Housing.Percent.That.Can.Be.Heated...     -0.781785        4.533150  -0.172460  8.630762e-01
# 40  Year.Built Multifamily.Housing.Percent.That.Ca...     -0.992200       14.119949  -0.070269  9.439792e-01
# 67              Estimated.Data.Flag...Natural.Gas_Yes     -1.104509        1.314123  -0.840491  4.006333e-01
# 56  Multifamily.Housing.Percent.That.Can.Be.Cooled...     -1.210265        0.649136  -1.864423  6.226226e-02
# 52  Multifamily.Housing.Percent.That.Can.Be.Cooled...     -1.269581        4.257497  -0.298199  7.655514e-01
# 83                      number.of.energy.meters.cat_5     -1.371104        0.420098  -3.263771  1.099401e-03
# 79                     number.of.energy.meters.cat_15     -1.482496        0.768572  -1.928897  5.374371e-02
# 80                     number.of.energy.meters.cat_20     -1.675388        1.582582  -1.058642  2.897629e-01
# 54  Multifamily.Housing.Percent.That.Can.Be.Cooled...     -2.263503        1.506610  -1.502382  1.329986e-01
# 64  Multifamily.Housing.Percent.That.Can.Be.Heated...     -2.851086        4.103979  -0.694713  4.872354e-01
# 82                    number.of.energy.meters.cat_25+     -2.925863        2.463886  -1.187499  2.350307e-01
# 59  Electricity.Use...Grid.Purchase.and.Generated....     -3.961281        2.205688  -1.795939  7.250424e-02
# 20  Weather.Normalized.Site.Natural.Gas.Intensity....     -4.571704        1.192196  -3.834691  1.257222e-04
# 19  Weather.Normalized.Site.Natural.Gas.Intensity....     -7.957109        8.304298  -0.958192  3.379661e-01
# 61  Longitude Multifamily.Housing.Percent.That.Can...     -9.294324      236.980578  -0.039220  9.687152e-01
# 25  Multifamily.Housing.Gross.Floor.Area.ft Multif...     -9.402974        8.059250  -1.166731  2.433192e-01
# 84  Multifamily.Housing.Resident.Population.Type_D...    -11.334864        5.239441  -2.163373  3.051252e-02
# 29  Multifamily.Housing.Gross.Floor.Area.ft ENERGY...    -13.701470       13.334449  -1.027524  3.041737e-01
# 73                   Property.Type_Mixed Use Property    -15.165080       23.795748  -0.637302  5.239281e-01
# 74                  Property.Type_Multifamily Housing    -15.172419       23.467445  -0.646530  5.179359e-01
# 43  Year.Built Multifamily.Housing.Percent.That.Ca...    -17.950593        9.020509  -1.989976  4.659363e-02
# 13  Weather.Normalized.Site.Natural.Gas.Intensity....    -26.423492        8.200141  -3.222322  1.271563e-03
# 36  Property.GFA.Calculated.Buildings.and.Parking....    -43.573183       38.281409  -1.138234  2.550230e-01
# 26  Multifamily.Housing.Gross.Floor.Area.ft Electr...    -50.683557       17.394804  -2.913718  3.571522e-03
# 75                               Property.Type_Office   -117.862291       40.484626  -2.911285  3.599453e-03
# 49  Latitude Multifamily.Housing.Percent.That.Can....   -138.209192      158.462051  -0.872191  3.831041e-01
# 62                        Longitude ENERGY.STAR.Score   -225.238796      728.870097  -0.309025  7.573028e-01
# 38  Property.GFA.Calculated.Buildings.and.Parking....   -238.053843      144.492948  -1.647512  9.945288e-02
# 31  Property.GFA.Calculated.Buildings.and.Parking....   -385.709725      246.364688  -1.565605  1.174412e-01
# 51        Latitude Percent.of.Electricity.Green.Power   -386.536913      181.659710  -2.127808  3.335304e-02
# 5                                            Latitude   -668.351158      347.525837  -1.923170  5.445874e-02
# 39                                Year.Built Latitude   -684.162295      107.241061  -6.379667  1.774731e-10
# 48                                 Latitude Longitude   -729.228047      324.796919  -2.245182  2.475648e-02
# 53  Multifamily.Housing.Percent.That.Can.Be.Cooled...   -749.296357      307.370494  -2.437763  1.477847e-02
# 6      Multifamily.Housing.Percent.That.Can.Be.Cooled  -1115.178494      361.400700  -3.085712  2.030654e-03
# 18  Weather.Normalized.Site.Natural.Gas.Intensity....  -1148.422675     1421.501579  -0.807894  4.191516e-01
# 24   Multifamily.Housing.Gross.Floor.Area.ft Latitude  -1937.330764     1906.328267  -1.016263  3.095042e-01
# 15  Weather.Normalized.Site.Natural.Gas.Intensity....  -3099.320103      415.431413  -7.460486  8.615331e-14
# 50                         Latitude ENERGY.STAR.Score  -3221.513931      255.023802 -12.632209  0.000000e+00
# 57  Electricity.Use...Grid.Purchase.and.Generated....  -3287.470375     1344.097194  -2.445858  1.445081e-02
# 47  Latitude Electricity.Use...Grid.Purchase.and.G...  -3748.706627      642.289166  -5.836478  5.331578e-09
# 2             Multifamily.Housing.Gross.Floor.Area.ft -10393.987261     4736.986544  -2.194219  2.821965e-02
# 27  Multifamily.Housing.Gross.Floor.Area.ft Longitude -12008.383220     4337.797734  -2.768313  5.634726e-03
